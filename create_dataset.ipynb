# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
covid_df = pd.read_csv('xRay_Corona/metadata.csv')
covid_df.head()
# Out:
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
# 2          2     5.0   M  65.0  COVID-19        Y       NaN
# 3          2     6.0   M  65.0  COVID-19        Y       NaN
# 4          4     0.0   F  52.0  COVID-19      NaN       NaN
#
#   intubation_present went_icu needed_supplemental_O2  ...              date  \
# 0                NaN      NaN                    NaN  ...  January 22, 2020
# 1                NaN      NaN                    NaN  ...  January 25, 2020
# 2                NaN      NaN                    NaN  ...  January 27, 2020
# 3                NaN      NaN                    NaN  ...  January 28, 2020
# 4                NaN      NaN                    NaN  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
covid_df.groupby('finding').count()
# Out:
#                 patientid  offset  sex  age  survival  intubated  \
# finding
# ARDS                    4       1    3    3         0          1
# COVID-19              284     213  246  236        76         63
# COVID-19, ARDS         12      12   12   12         4          5
# Chlamydophila           2       2    2    2         2          0
# E.Coli                  4       4    4    4         4          0
# Klebsiella              1       0    1    1         0          0
# Legionella              2       0    2    2         0          0
# No Finding              3       2    3    3         2          3
# Pneumocystis           15       0   12   10         3          0
# SARS                   16      14   16   16        11          0
# Streptococcus          17      16   16   17         7          0
#
#                 intubation_present  went_icu  needed_supplemental_O2  \
# finding
# ARDS                             1         0                       0
# ...

# %%
covid_df = covid_df[lambda x: x['view'] == 'PA']
covid_df.shape
# Out:
# (208, 28)

# %%
covid_df = covid_df[covid_df['finding'].isin(['COVID-19', 'COVID-19, ARDS'])]
covid_df.shape
# Out:
# (156, 28)

# %%
covid_df = covid_df[['folder', 'filename']]
covid_df
# Out:
#      folder                                           filename
# 0    images  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...
# 1    images  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...
# 2    images  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...
# 3    images  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...
# 4    images                              nejmc2001573_f1a.jpeg
# 5    images                              nejmc2001573_f1b.jpeg
# 7    images                                  lancet-case2a.jpg
# 8    images                                  lancet-case2b.jpg
# 20   images               1-s2.0-S0140673620303706-fx1_lrg.jpg
# 21   images              nCoV-radiol.2020200269.fig1-day7.jpeg
# 22   images                           nejmoa2001191_f1-PA.jpeg
# 24   images                           nejmoa2001191_f3-PA.jpeg
# 26   images                              nejmoa2001191_f4.jpeg
# 27   images                           nejmoa2001191_f5-PA.jpeg
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train, test, _, __ = train_test_split(covid_df['filename'], covid_df['folder'], test_size = 0.2)

# %%
train.shape
# Out:
# (124,)

# %%
test.shape
# Out:
# (32,)

# %%
or_path = 'xRay_Corona/images'
import shutil

# %%
for i in train:
    shutil.copyfile(or_path+'/'+i, 'data/train/positive/'+i)

# %%
for i in test:
    shutil.copyfile(or_path+'/'+i, 'data/test/positive/'+i)
